# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
#os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

import random
from collections import Counter
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 30})
import pandas as pd
import numpy as np
import tensorflow as tf
import glob
import scipy.interpolate
from scipy.interpolate import interp1d
from src.utils.Notebook_imports import *
from src.data.Preprocess import clip_quantile
from src.data.Dataset import load_phase_reg_exp
from src.visualization.Visualize import show_2D_or_3D

from ipywidgets import interact
import ipywidgets as widgets
from IPython.core.display import display, HTML
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/cmr-phase-detection

# %% [markdown]
# # Load phase-vector and gt/pred from a project

# %%
# List of 4D Files
# Read file, convert to nda
# Apply method
# Visualize Center
# Compare Center with Septum or LV COM
# Apply crop to mask, calculate Dice between original maks and cropped

# %%
from ipyfilechooser import FileChooser
vects_chooser = FileChooser(os.path.join(os.getcwd(),'/mnt/ssd/git/dynamic-cmr-models/exp/phasereg_v3/acdc/'), '')
display(vects_chooser)
# Out:
# FileChooser(path='/mnt/ssd/git/dynamic-cmr-models/exp/phasereg_v3/acdc', filename='', title='HTML(value='', la…

# %%
# load the vectors
temp = vects_chooser.selected
#temp = '/mnt/ssd/git/dynamic-cmr-models/exp/phasereg_v3/roll2/mse/phaseloss0_2lstm32_acdc/2022-03-30_18_56/'
# load all files of this experiment
nda_vects, gt, pred, gt_len, mov, patients = load_phase_reg_exp(temp)

# %%
# plot one moved timestep of one patient = one 3D volume 
# should go from apex to base
from src.visualization.Visualize import show_2D_or_3D
example = 20
# apex to base, one t
t0_moved = mov[example,0,...,0]
_ = show_2D_or_3D(t0_moved, cmap='gray', interpolation='none')
# one slice over time
z8_moved = mov[example,:,8,...,0]
_ = show_2D_or_3D(z8_moved, cmap='gray', interpolation='none')

# %%
t0_vect = nda_vects[example,0,...]
_ = show_2D_or_3D(t0_vect, interpolation='none')
z8_vect = nda_vects[example,:,8,...]
_ = show_2D_or_3D(z8_vect, interpolation='none')

# %% [markdown]
# # Import / define some helper functions

# %%
import tensorflow as tf
import sys
from src.models.KerasLayers import get_angle_tf,get_angle_np, get_centers_tf,get_idxs_tf
# define two lambdas as wrapper for the angle and min/max normalisation within variable ranges
minmax_lambda = lambda x : x[1] + (((x[0] - np.min(x[0])) * (x[2]-x[1]))/(np.max(x[0]) - np.min(x[0])+sys.float_info.epsilon))
# define some central params
lower, mid, upper = -1,0, 1

# %%
# returns a matrix with vectors pointing to the focus point C
def get_focus_tf(p,dim=[12,12,12]):
    return tf.cast(
        tf.tile(tf.convert_to_tensor([*p])[tf.newaxis, tf.newaxis, tf.newaxis, ...],
                (*dim, 1)), tf.float32)

flow2direction_lambda2 = tf.keras.layers.Lambda(
            lambda x: get_angle_tf(x[0], x[1]), name='flow2direction')
print(nda_vects.shape)
dim = np.array(nda_vects.shape[2:-1])
# Out:
# (278, 40, 16, 64, 64, 3)

# %%
# define df and helper for pathology extractio
# this should have the same order as our inference data
#df_meta = pd.read_csv(folds_chooser.selected)
df_meta = pd.read_csv('/mnt/sds/sd20i001/sven/data/acdc/02_imported_4D_unfiltered/df_kfold.csv')
df_meta = df_meta.loc[:, ~df_meta.columns.str.contains('^Unnamed')]
df_meta = df_meta[df_meta.patient != 'patient090']  #we excluded this patient
df_meta
# Out:
#       fold modality pathology     patient phase  \
# 0        3    train      MINF  patient050    ED
# 1        3    train      MINF  patient050    ES
# 2        3    train       NOR  patient070    ED
# 3        3    train       NOR  patient070    ES
# 4        3    train        RV  patient100    ES
# ...    ...      ...       ...         ...   ...
# 1595     0    train       NOR  patient072    ED
# 1596     0    train      MINF  patient045    ES
# 1597     0    train      MINF  patient045    ED
# 1598     0    train       HCM  patient032    ES
# 1599     0    train       HCM  patient032    ED
#
#                                                  x_path  \
# 0     data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1     data/raw/ACDC/3D/all/patient050/patient050_fra...
# 2     data/raw/ACDC/3D/all/patient070/patient070_fra...
# 3     data/raw/ACDC/3D/all/patient070/patient070_fra...
# 4     data/raw/ACDC/3D/all/patient100/patient100_fra...
# ...                                                 ...
# 1595  data/raw/ACDC/3D/train/patient072/patient072_f...
# 1596  data/raw/ACDC/3D/train/patient045/patient045_f...
# 1597  data/raw/ACDC/3D/train/patient045/patient045_f...
# 1598  data/raw/ACDC/3D/train/patient032/patient032_f...
# 1599  data/raw/ACDC/3D/train/patient032/patient032_f...
#
#                                                  y_path
# 0     data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1     data/raw/ACDC/3D/all/patient050/patient050_fra...
# 2     data/raw/ACDC/3D/all/patient070/patient070_fra...
# 3     data/raw/ACDC/3D/all/patient070/patient070_fra...
# 4     data/raw/ACDC/3D/all/patient100/patient100_fra...
# ...                                                 ...
# 1595  data/raw/ACDC/3D/train/patient072/patient072_f...
# 1596  data/raw/ACDC/3D/train/patient045/patient045_f...
# 1597  data/raw/ACDC/3D/train/patient045/patient045_f...
# 1598  data/raw/ACDC/3D/train/patient032/patient032_f...
# 1599  data/raw/ACDC/3D/train/patient032/patient032_f...
#
# [1584 rows x 7 columns]

# %%
patients_df = pd.DataFrame(patients, columns=['pat'])
patients_df['patient'] = patients_df['pat'].map(lambda x : x.split('_')[1])
patients_df['fold'] = patients_df['pat'].map(lambda x : x.split('_')[0])
patients_df
# Out:
#                                                 pat        patient fold
# 0    0_0000-11yu3cuf_2007-12-10_volume_clean.nrrd\n  0000-11yu3cuf    0
# 1    0_0000-1e4pf7mr_2006-07-06_volume_clean.nrrd\n  0000-1e4pf7mr    0
# 2    0_0000-1e8mcv9l_2005-12-15_volume_clean.nrrd\n  0000-1e8mcv9l    0
# 3    0_0000-1tk4rv5f_2006-05-19_volume_clean.nrrd\n  0000-1tk4rv5f    0
# 4    0_0000-1ujmwcty_2006-09-01_volume_clean.nrrd\n  0000-1ujmwcty    0
# ..                                              ...            ...  ...
# 273  3_0000-z0qr21cj_2005-11-02_volume_clean.nrrd\n  0000-z0qr21cj    3
# 274  3_0000-zfr7wrgf_2005-11-01_volume_clean.nrrd\n  0000-zfr7wrgf    3
# 275  3_0000-zl87chv6_2005-10-20_volume_clean.nrrd\n  0000-zl87chv6    3
# 276  3_0000-zxr60d6k_2003-10-01_volume_clean.nrrd\n  0000-zxr60d6k    3
# 277  3_0000-zzq0001q_2007-03-29_volume_clean.nrrd\n  0000-zzq0001q    3
#
# [278 rows x 3 columns]

# %%
temp = df_meta[df_meta['modality'] == 'test']
temp = temp[temp['phase']=='ED'].drop_duplicates(ignore_index=True, subset='patient')
merged_temp = pd.merge(left=patients_df, right=temp, how='inner', left_on='patient', right_on='patient')
merged_temp
# Out:
# Empty DataFrame
# Columns: [pat, patient, fold_x, fold_y, modality, pathology, phase, x_path, y_path]
# Index: []

# %% [markdown]
# # make sure the general method works

# %%
temp = get_focus_tf(dim//2,dim)
temp2 = get_centers_tf(dim)
(temp == temp2).numpy().all()
# Out:
# True

# %% [markdown]
# # plot the direction per patient

# %%
@interact
def show_direction(example=(0,nda_vects.shape[0]-1)):
    print('patient: {}'.format(example))
    print(t0_vect.shape)
    cardiac_length = int(gt_len[example][:,0].sum())
    dim = np.array([16,64,64])
    idx = get_idxs_tf(dim)
    c = get_focus_tf(dim//2,dim)
    centers = c - idx
    centers_tensor = centers[tf.newaxis, ...]
    # get the direcrion towards any focus point
    # direction
    directions = get_angle_np(nda_vects[example,...],centers_tensor)[...,0]
    # direction mean
    directions = np.mean(directions,axis=(1,2,3))
    plt.plot(directions[:cardiac_length]); plt.show()
    plt.imshow(gt[example].T[:,:cardiac_length]);plt.show()
# Out:
# interactive(children=(IntSlider(value=138, description='example', max=277), Output()), _dom_classes=('widget-i…

# %% [markdown]
# # highlight areas with maximal difference in direction

# %%
@interact
def show_direction(example=(0,nda_vects.shape[0]-1)):
    print('patient: {}'.format(example))
    print(t0_vect.shape)
    fig, axes = plt.subplots(2,2, figsize=(15,5))
    cardiac_length = int(gt_len[example][:,0].sum())
    dim = np.array([16,64,64])
    idx = get_idxs_tf(dim)
    c = get_focus_tf(dim//2,dim)
    centers = c - idx
    centers_tensor = centers[tf.newaxis, ...]
    # get the direcrion towards any focus point
    # direction
    directions = get_angle_np(nda_vects[example,...],centers_tensor)[...,0]
    # direction mean
    directions = np.mean(directions,axis=(1,2,3))
    axes[0,0].plot(directions[:cardiac_length])
    axes[1,0].imshow(gt[example].T[:,:cardiac_length]);plt.show()
# Out:
# interactive(children=(IntSlider(value=138, description='example', max=277), Output()), _dom_classes=('widget-i…

# %% [markdown]
# # interactive direction visualisation

# %%
phases = ['ED', 'MS', 'ES', 'PF', 'MD']
if 'comb_dir' not in locals():
    print('recreate comb dir')
min_dir = np.zeros((nda_vects.shape[0],16,64,64))
max_dir = np.zeros((nda_vects.shape[0],16,64,64))
comb_dir= np.zeros((nda_vects.shape[0],16,64,64))
import scipy
import scipy.misc
@interact
def show(e=(0,nda_vects.shape[0]-1),
         t=(0,nda_vects.shape[1]-1),
        cz=(0,nda_vects.shape[2]-1),
        cx=(0,nda_vects.shape[3]-1),
        cy=(0,nda_vects.shape[4]-1),
         show= ['cmr','norm','mse','dir','heatmap', 'diff_dir'],
        mask=['none', 'norm','mse'],
        msk_t=(0.0,1.0,0.01),
        diff_t=(0.0,1.0,0.01),
        c_focus=['coord','norm','mse'],
        reduce=['none','mean', 'median','max']):
    
    ct = np.array([cz,cy,cx])
    patient_id = patients[e].split('_')[1]
    cardiac_length = int(gt_len[e][:,0].sum())
    print('patient: {}, pathology: {}'.format(patient_id, merged_temp[merged_temp['patient'] == patient_id]['pathology']))
    fig, (ax1,ax2) = plt.subplots(1,2, figsize=(14,8))
    
    # we have e, t, z --> 2D
    # select two following 2D CMR slices from mov
    # select a 2D vect slice
    
    # calc the norm for this 2D vector slice
    # calc the mse between both following CMR
    # create an empty mask, or based on the norm or the mse
    # if msk_norm or msk_mse, mask the mse, the norm and the 2D vector slice
    
    # calc the com for the norm
    # calc the com for the mse
    
    # define the C_focus matrix based on c_coord, c_norm, c_mse
    # calc the direction based on the masked vect_slice and C_focus as volume with z ==1
    
    
    # get cmr and vect for patient e
    mov_full = minmax_lambda([mov[e,...],0,1])
    mov_full_rolled = np.roll(mov_full, shift=-1,axis=0)
    vect_full = nda_vects[e,...]
    
    # for imshow get the current 2D
    movt_slice = mov_full[t,cz,...,0]
    movtplus_slice = mov_full_rolled[t,cz, ...,0]
    vect_slice = vect_full[t,cz,...]
    
    # calc norm for the 4D volume between t and t+1
    norm_ = np.linalg.norm(vect_full,axis=-1)
    norm_ = clip_quantile(norm_, 0.99)
    #norm_ = np.stack([minmax_lambda([elem,0,1]) for elem in norm_], axis=0) # normalise per t, to scope with the cardiac dynamic
    
    # calc mse for the 4D volume between t and t+1
    mse_ = tf.keras.metrics.mean_squared_error(mov_full,mov_full_rolled).numpy()
    mse_ = clip_quantile(mse_, 0.99)
    #mse_ = np.stack([minmax_lambda([elem,0,1]) for elem in mse_], axis=0) # normalise per t, to scope with the cardiac dynamic
    
    # reduce the norm along t by one of the following operations, broadcast afterwards
    t_shape = norm_.shape[0]
    if reduce=='mean':
        norm_ = np.mean(norm_, axis=0)
        mse_ = np.mean(mse_, axis=0)
    elif reduce=='median':
        norm_ = np.median(norm_, axis=0)
        mse_ = np.median(mse_, axis=0)
    elif reduce=='max':
        norm_ = np.max(norm_, axis=0)
        mse_ = np.max(mse_, axis=0)
    # broadcast the temporal reduced matrix into the original shape
    if reduce in ['mean', 'median','max']:
        norm_ = np.broadcast_to(norm_,shape=(t_shape,*norm_.shape))
        mse_ = np.broadcast_to(mse_,shape=(t_shape,*mse_.shape))
        
    norm_slice = minmax_lambda([norm_[t,cz],0,1])
    mse_slice = minmax_lambda([mse_[t,cz],0,1])
    
    if mask=='norm':
        msk = (norm_>=np.quantile(norm_, msk_t)).astype(np.float32)
    elif mask=='mse':
        msk = (mse_>=np.quantile(mse_, msk_t)).astype(np.float32)
    else:
        msk = np.ones_like(mse_)
    msk_slice = msk[t,cz]
        
    norm_slice = norm_slice * msk_slice
    mse_slice = mse_slice * msk_slice
    
    border = 1
    # alternative calculation, tf ready
    # yf,xf = np.where(mse_slice>dif_t)
    # yf,xf = np.mean(yf),np.mean(xf)
    mse_com = scipy.ndimage.center_of_mass(mse_slice[border:-border,border:-border])
    mse_com = np.array(mse_com) + border
    print('com mse>dif_t: {}'.format(mse_com))
    
    norm_com = scipy.ndimage.center_of_mass(norm_slice[border:-border,border:-border])
    norm_com = np.array(norm_com) + border
    print('com norm>dif_t: {}'.format(norm_com))

    # directions as heatmap for each x,y,z voxel
    heatmap = comb_dir[e,cz]
    ind = np.where(heatmap==np.max(heatmap)) 
    ind_min = np.where(min_dir[e,cz]==np.min(min_dir[e,cz]))
    ind_max = np.where(max_dir[e,cz]==np.max(max_dir[e,cz]))      
    
    if c_focus == 'mse':
        ct=np.array((cz,mse_com[0],mse_com[1]))
    elif c_focus == 'norm':
        ct=np.array((cz,norm_com[0],norm_com[1]))
    else:
        ct=np.array((cz,cy,cx))
        
          
    dim = np.array([16,64,64])
    idx = get_idxs_tf(dim)
    c = get_focus_tf(ct,dim)
    centers = c - idx
    centers_tensor = centers[tf.newaxis, ...]
    
    # direction 2D
    dir_ = get_angle_np(vect_full,centers_tensor)[...,0]
    #print('dir', dir_.shape)
    dir_slice = dir_[t,cz]*msk_slice
    
    # direction 1D + t
    dir_ = dir_ * msk
    dir_1d = np.mean(dir_, axis=(1,2,3))
    
    # find areas with max difference in the direction along t
    dir_scaled = minmax_lambda([dir_,-1,1])*(norm_*100)
    diff_dir = np.max(dir_scaled, axis=0) - np.min(dir_scaled,axis=0)
    print(diff_dir.shape)
    
    norm_ = norm_ * msk
    norm_1d = np.mean(norm_, axis=(1,2,3))
    
    orig= 'upper'
    alpha = 0.4
    print('max diff of {} at y,x: {}'.format(np.max(heatmap), ind))
    #print(ind[1][0],ind[0][0])
    #ax1.scatter(ind_min[1][0],ind_min[0][0], label='min',c='orange', marker='<')
    #ax1.scatter(ind_max[1][0],ind_max[0][0], label='max',c='orange', marker='o')
    ax1.scatter(ind[1][0],ind[0][0], label='com',s=100,c='orange', marker='x')
    ax1.scatter(cx,cy, c='pink', label='select',s=100,marker='o')
    # focus point based on com of sum mse along t
    ax1.scatter(norm_com[1],norm_com[0], c='red',s=100, label='norm_com',marker='<')
    ax1.scatter(mse_com[1],mse_com[0], c='red',s=100, label='mse_com',marker='o')
    ax1.legend(loc='lower right')
    
    im = ax1.imshow(movt_slice, cmap='gray',alpha=1,origin=orig)
    
    if show == 'heatmap': 
        im = ax1.imshow(minmax_lambda([comb_dir[e,cz],0,1]), alpha=alpha,origin=orig)
    elif show == 'norm': 
        im = ax1.imshow(norm_slice, origin=orig, alpha=alpha, cmap='hot')
        
    elif show == 'dir':
        im = ax1.imshow(dir_slice, origin=orig, alpha=alpha, cmap='bwr')
        
    elif show == 'mse':
        im = ax1.imshow(mse_slice, origin=orig, alpha=alpha, cmap='hot')
    elif show == 'diff_dir':
        im = ax1.imshow(minmax_lambda([diff_dir[cz],0,1])>diff_t, alpha=alpha,origin=orig)
    
    fig.colorbar(im, orientation='horizontal')
    #_ = ax1.imshow(movt_slice, cmap='gray',alpha=alpha,origin=orig)
    
    
    ax2.imshow(gt[e].T[:,:cardiac_length])
    ax2.set_yticks(range(len(phases)), minor=False)
    ax2.set_yticklabels(phases, rotation=0)
    ax3 = ax2.twinx()
    ax3.plot(dir_1d[:cardiac_length], c = 'red')
    #ax3.plot(norm_1d, c = 'blue')
    if mask:
        ax3.set_ylim([-0.2,0.2])
    else:
        ax3.set_ylim([-0.3,0.3])
    
    ax3.axvline(x=t)
    
    plt.show()
# Out:
# interactive(children=(IntSlider(value=138, description='e', max=277), IntSlider(value=19, description='t', max…

# %%
# b,t,z,x,y
import concurrent
from concurrent.futures import as_completed
from time import time
from src.data.Preprocess import clip_quantile

def helper(c_t, e,cz,cy,cx):
    #print(cx,cy)
    # focus point C
    ct = np.array([cz,cy,cx])
    dim = np.array([16,64,64])
    idx = get_idxs_tf(dim)
    c = get_focus_tf(ct,dim)
    centers = c - idx
    centers_tensor = centers[tf.newaxis, ...]

    # direction
    directions = get_angle_np(c_t,centers_tensor)[...,0]
    
    # mask v_t by a threshold norm
    norm_nda = np.linalg.norm(c_t, axis=-1)
    norm_nda = clip_quantile(norm_nda, 0.99)
    norm_nda = minmax_lambda([norm_nda,0,1])
    norm_msk = minmax_lambda([np.max(norm_nda, axis=1),0,1])
    norm_msk = (norm_msk>=0.0).astype(np.float32)[np.newaxis,...] # this could be used to mask v_t by a threshold norm
    directions = directions * norm_msk
    

    # direction mean
    directions = np.mean(directions,axis=(2,3,4))
    min_d = np.min(directions, axis=1)
    max_d = np.max(directions, axis=1)
    comb_d = abs(min_d) + abs(max_d)
    return ct, e, min_d, max_d, comb_d
    

futures = set()
#e = 1
window = 1
step_z = 4
step_x = step_y = 8
cz = 0
t0 = time()
with concurrent.futures.ThreadPoolExecutor(max_workers=12) as executor:
    for e in range(0,nda_vects.shape[0]-1,window):
        for cz in range(0,nda_vects.shape[2],step_z):
            for cx in range(0,nda_vects.shape[3],step_x):
                for cy in range(0,nda_vects.shape[4],step_y):
                    futures.add(executor.submit(helper, nda_vects[e:e+window], e,cz,cy,cx))
                    #print(cx,cy)
        #print('patient: {}'.format(e))
print('all threads started : {}'.format(time()- t0))
# Out:
# all threads started : 1916.4864249229431

# %%
for i, future in enumerate(as_completed(futures)):
    ct,e, min_d,max_d,comb_d = future.result()
    cz,cy,cx = ct
    min_dir[e:e+window,cz,cy,cx] = min_d
    max_dir[e:e+window,cz,cy,cx] = max_d
    comb_dir[e:e+window,cz,cy,cx] = comb_d

# %%
len(futures)
# Out:
# 25088

# %%
mov[0].shape
# Out:
# (40, 16, 64, 64, 1)

# %%
from src.utils.Metrics import SSIM
elem = 0
y_true = mov[elem][None,...]
y_pred = np.roll(mov[elem],axis=0, shift=-1)[None,...]

shape_ytrue = y_true.shape
t_shape = (shape_ytrue[0],shape_ytrue[-3],shape_ytrue[-2],shape_ytrue[1]*shape_ytrue[2])
#from skimage.metrics import structural_similarity as ssim_fn
#ssim = ssim_fn(im1=y_true, im2=y_pred, multichannel=True)
img1 = tf.reshape(tensor=y_true, shape=t_shape)
img2 = tf.reshape(tensor=y_pred, shape=t_shape)
ssim = tf.image.ssim(img1, img2, max_val=1.0, filter_size=11,
              filter_sigma=1.5, k1=0.01, k2=0.03)
1- ssim
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.04075325], dtype=float32)>

# %% [markdown]
# # Find focus point unsupervised via mean squared error over time

# %%
import tensorflow as tf
@interact
def show_mse_center(e=(0,mov.shape[0]-1), threshold=(0.0,1.0,0.01)):
    #threshold = 0.01
    
    temp = mov[e]
    temp_roll = np.roll(temp, shift=-1,axis=0)
    mse_ = tf.keras.metrics.mean_squared_error(temp,temp_roll).numpy()
    mse_mean = np.mean(mse_,axis=0)
    thresh = np.quantile(mse_mean,threshold)
    print(thresh)
    zf,yf,xf = np.where(mse_mean>thresh)
    print(zf.mean(),xf.mean(), yf.mean())
    comz, comy, comx = scipy.ndimage.center_of_mass(mse_mean)
    print(comz, comy, comx)
    plt.hist(mse_.flatten())
    _= show_2D_or_3D(temp[0], mse_mean>thresh)
    plt.show()
# Out:
# interactive(children=(IntSlider(value=138, description='e', max=277), FloatSlider(value=0.5, description='thre…

# %%
np.save('data/predicted/min_max_comb_direction_per_voxel_acdc_center.npz',np.stack([min_dir,max_dir, comb_dir]))

# %%
# acdc
files_ = sorted(glob.glob('/mnt/ssd/data/acdc/02_imported_4D_unfiltered/sax/patient*nii.gz'))
@interact
def show_mse_center(e=(0,len(files_)-1), threshold=(0.0,1.0,0.01)):
    #threshold = 0.01
    f = files_[e]
    temp = sitk.GetArrayFromImage(sitk.ReadImage(f)).astype(float)[...,None]
    print(temp.shape)
    temp_roll = np.roll(temp, shift=-1,axis=0)
    mse_ = tf.keras.metrics.mean_squared_error(temp,temp_roll).numpy()
    print(mse_.shape)
    mse_mean = np.mean(mse_,axis=0)
    print(mse_mean.shape)
    thresh = np.quantile(mse_mean,threshold)
    print(thresh)
    zf,yf,xf = np.where(mse_mean>thresh)
    print(zf.mean(),xf.mean(), yf.mean())
    comz, comy, comx = scipy.ndimage.center_of_mass(mse_mean)
    print(comz, comy, comx)
    plt.hist(temp.flatten())
    fig = show_2D_or_3D(temp[0], mse_mean>thresh,figsize=(10,10))
    print(len(fig.axes))
    for i,ax in enumerate(fig.axes):
        yf,xf = np.where(mse_mean[i]>thresh)
        ax.scatter(int(xf.mean()),int(yf.mean()), c='red', label='select',s=100,marker='o')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=49, description='e', max=98), FloatSlider(value=0.5, description='thresh…

# %%
# tof
files_ = sorted(glob.glob('/mnt/ssd/data/tof/export/sax/*clean*'))
@interact
def show_mse_center(e=(0,len(files_)-1), threshold=(0.0,1.0,0.01)):
    #threshold = 0.01
    f = files_[e]
    temp = sitk.GetArrayFromImage(sitk.ReadImage(f)).astype(float)[...,None]
    print(temp.shape)
    
    t, nz, ny, nx,c = temp.shape
    include_slices = int(nz*.3)
    border_percentage = 20
    nyx = np.array([int(ny), int(nx)])
    border = ((nyx / 100) * border_percentage).astype(int)

    # take only the basal area and exclude areas close to the border
    temp = temp#[:,:include_slices,border[0]:-border[0], border[1]:-border[1],:]
    
    temp_roll = np.roll(temp, shift=-1,axis=0)
    mse_ = tf.keras.metrics.mean_squared_error(temp,temp_roll).numpy()
    print(mse_.shape)
    mse_mean = np.mean(mse_,axis=0)
    mse_mean_cut = mse_mean[:include_slices,border[0]:-border[0], border[1]:-border[1]]
    print(mse_mean.shape)
    thresh = np.quantile(mse_mean_cut,threshold)
    print(thresh)
    zf,yf,xf = np.where(mse_mean_cut>thresh)
    print(zf.mean(),xf.mean(), yf.mean())
    comz, comy, comx = scipy.ndimage.center_of_mass(mse_mean_cut)
    print(comz, comy, comx)
    plt.hist(temp.flatten())
    fig = show_2D_or_3D(temp[0], mse_mean>thresh,figsize=(10,10))
    print(len(fig.axes))
    for i,ax in enumerate(fig.axes):
        if i<mse_mean_cut.shape[0]:
            yf,xf = np.where(mse_mean_cut[i]>thresh)
            ax.scatter(int(xf.mean() + border[0]),int(yf.mean() + border[1]), c='red', label='select',s=100,marker='o')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=139, description='e', max=278), FloatSlider(value=0.5, description='thre…

# %%
# ukbio
files_ = sorted(glob.glob('/mnt/ssd/data/ukbio/patient_test/cmr4d.nrrd'))
@interact
def show_mse_center(e=(0,len(files_)-1), threshold=(0.0,1.0,0.01)):
    #threshold = 0.01
    f = files_[e]
    temp = sitk.GetArrayFromImage(sitk.ReadImage(f)).astype(float)[...,None]
    print(temp.shape)
    temp_roll = np.roll(temp, shift=-1,axis=0)
    mse_ = tf.keras.metrics.mean_squared_error(temp,temp_roll).numpy()
    print(mse_.shape)
    mse_mean = np.mean(mse_,axis=0)
    print(mse_mean.shape)
    thresh = np.quantile(mse_mean,threshold)
    print(thresh)
    zf,yf,xf = np.where(mse_mean>thresh)
    print(zf.mean(),xf.mean(), yf.mean())
    comz, comy, comx = scipy.ndimage.center_of_mass(mse_mean)
    print(comz, comy, comx)
    plt.hist(temp.flatten())
    fig = show_2D_or_3D(temp[0], mse_mean>thresh,figsize=(10,10))
    print(len(fig.axes))
    for i,ax in enumerate(fig.axes):
        yf,xf = np.where(mse_mean[i]>thresh)
        ax.scatter(int(xf.mean()),int(yf.mean()), c='red', label='select',s=100,marker='o')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='e', max=0), FloatSlider(value=0.5, description='threshol…

# %%
# tof boston
files_ = sorted(glob.glob('/mnt/ssd2/tof_bosten/export*/*.nrrd'))
@interact
def show_mse_center(e=(0,len(files_)-1), threshold=(0.0,1.0,0.01)):
    #threshold = 0.01
    f = files_[e]
    temp = sitk.GetArrayFromImage(sitk.ReadImage(f)).astype(float)[...,None]
    print(temp.shape)
    
    t, nz, ny, nx,c = temp.shape
    include_slices = int(nz*.3)
    border_percentage = 20
    nyx = np.array([int(ny), int(nx)])
    border = ((nyx / 100) * border_percentage).astype(int)

    # take only the basal area and exclude areas close to the border
    temp = temp#[:,:include_slices,border[0]:-border[0], border[1]:-border[1],:]
    
    temp_roll = np.roll(temp, shift=-1,axis=0)
    mse_ = tf.keras.metrics.mean_squared_error(temp,temp_roll).numpy()
    print(mse_.shape)
    mse_mean = np.mean(mse_,axis=0)
    mse_mean_cut = mse_mean[:include_slices,border[0]:-border[0], border[1]:-border[1]]
    print(mse_mean.shape)
    thresh = np.quantile(mse_mean_cut,threshold)
    print(thresh)
    zf,yf,xf = np.where(mse_mean_cut>thresh)
    print(zf.mean(),xf.mean(), yf.mean())
    comz, comy, comx = scipy.ndimage.center_of_mass(mse_mean_cut)
    print(comz, comy, comx)
    plt.hist(temp.flatten())
    fig = show_2D_or_3D(temp[0], mse_mean>thresh,figsize=(10,10))
    print(len(fig.axes))
    for i,ax in enumerate(fig.axes):
        if i<mse_mean_cut.shape[0]:
            yf,xf = np.where(mse_mean_cut[i]>thresh)
            ax.scatter(int(xf.mean() + border[0]),int(yf.mean() + border[1]), c='red', label='select',s=100,marker='o')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=320, description='e', max=641), FloatSlider(value=0.5, description='thre…
